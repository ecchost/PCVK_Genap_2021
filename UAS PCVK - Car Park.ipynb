# %% [markdown]
# <a href="https://colab.research.google.com/github/ecchost/PCVK_Genap_2021/blob/main/UAS%20PCVK%20-%20Car%20Park.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SO CROWDED

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive')

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK/Car-Park/2012-11-09_08_31_37.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Crowded Level : ")
if (number_of_white_pix > 3000):
    print("So Crowded")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Crowded")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Less Crowded")
elif (number_of_white_pix < 100):
    print("Least")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Mounted at /content/drive
# Number of white pixels: 3213
# Number of black pixels: 10216
# Crowded Level :
# So Crowded
# Accurate percentage :  23.925832154292948 %

# %% [markdown]
# # CROWDED

# %%
#Test with other images - CROWDED
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive')

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK/Car-Park/2012-11-09_12_26_48.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Crowded Level : ")
if (number_of_white_pix > 3000):
    print("So Crowded")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Crowded")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Less Crowded")
elif (number_of_white_pix < 100):
    print("Least")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Number of white pixels: 1216
# Number of black pixels: 10502
# Crowded Level :
# Crowded
# Accurate percentage :  10.377197473971668 %

# %% [markdown]
# # LESS CROWDED

# %%
#Test with other images 2 - LESS CROWDED
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive')

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK/Car-Park/2012-11-09_07_06_33.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Crowded Level : ")
if (number_of_white_pix > 3000):
    print("So Crowded")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Crowded")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Less Crowded")
elif (number_of_white_pix < 100):
    print("Least")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Number of white pixels: 371
# Number of black pixels: 6156
# Crowded Level :
# Less Crowded
# Accurate percentage :  5.684081507583882 %

# %% [markdown]
# # LEAST

# %%
#Test with other images 3 - LEAST
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive')

#image Path
img0 = cv.imread('/content/drive/MyDrive/PCVK/Car-Park/2012-11-09_06_36_31.jpg')

#convert to grayscale
gray = cv.cvtColor(img0, cv.COLOR_BGR2GRAY)

#removing noises
img = cv.GaussianBlur(gray,(3,3),0)

#sobel edge detection
img_sobelx = cv.Sobel(img, cv.CV_64F, 1, 0, ksize=3)
img_sobely = cv.Sobel(img, cv.CV_64F, 0, 1, ksize=3)

img_sobelxy = cv.addWeighted(cv.convertScaleAbs(img_sobelx), 0.5, cv.convertScaleAbs(img_sobely), 0.5, 0)

f, axarr = plt. subplots(1,2,figsize=(15,5))
plt.subplot(121),plt.imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
axarr[0].imshow(cv.cvtColor(img0, cv.COLOR_BGR2RGB))
plt.subplot(122),plt.imshow(img_sobelxy,cmap = 'gray')

#calculate white and black pixel
number_of_white_pix = np.sum(img_sobelxy == 255)
number_of_black_pix = np.sum(img_sobelxy == 0)
  
print('Number of white pixels:', number_of_white_pix)
print('Number of black pixels:', number_of_black_pix)

#Create Category by Data Range
print("Crowded Level : ")
if (number_of_white_pix > 3000):
    print("So Crowded")
elif (number_of_white_pix >= 1000 and number_of_white_pix <= 2999):
    print("Crowded")
elif (number_of_white_pix >= 100 and number_of_white_pix <= 999):
    print("Less Crowded")
elif (number_of_white_pix < 100):
    print("Least")

threshold = (number_of_white_pix/(number_of_white_pix + number_of_black_pix)) * 100

print("Accurate percentage : ", threshold, "%")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Number of white pixels: 89
# Number of black pixels: 3862
# Crowded Level :
# Least
# Accurate percentage :  2.2525942799291316 %
